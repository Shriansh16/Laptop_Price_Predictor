# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('laptop_price.csv',encoding='latin-1')

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df.isnull().sum()
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df['price_rs']=df['Price_euros']*87.90

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns='laptop_ID',axis=1,inplace=True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros    price_rs
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69  117758.751
# ...

# %%
df['Ram']=df['Ram'].str.replace('GB','')

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros    price_rs
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69  117758.751
# ...

# %%
df['Weight']=df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight  Price_euros    price_rs
# 0  Intel Iris Plus Graphics 640  macOS   1.37      1339.69  117758.751
# ...

# %%
df.drop('Price_euros',axis=1,inplace=True)

# %%
df['Weight']=df['Weight'].astype(float)

# %%
df['Ram']=df['Ram'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float64
#  11  price_rs          1303 non-null   float64
# dtypes: float64(3), int32(1), object(8)
# memory usage: 117.2+ KB

# %%
sns.distplot(df['price_rs'])
# Out:
# <AxesSubplot:xlabel='price_rs', ylabel='Density'>

# %% [markdown]
# ## THE PRICE OF MOST OF THE LAPTOPS ARE LESS

# %%
df['Company'].value_counts().plot.pie(y=df['Company'],figsize=(30,25),autopct='%1.1f')
# Out:
# <AxesSubplot:ylabel='Company'>

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
k=df.groupby('Company',as_index=False).mean().sort_values(by='price_rs')

# %%
k
# Out:
#       Company     Inches        Ram    Weight       price_rs
# 17       Vero  13.825000   3.500000  1.330000   19111.657500
# 12   Mediacom  13.457143   3.714286  1.337143   25930.500000
# 3       Chuwi  14.500000   4.666667  1.726667   27626.677000
# 0        Acer  15.063107   5.980583  2.166893   55093.595039
# 5     Fujitsu  15.600000   6.666667  2.233333   64079.100000
# 7          HP  14.943066   6.912409  1.911314   93857.409668
# 10     Lenovo  14.872727   8.040404  2.002290   95493.192667
# 2        Asus  15.450000   9.594937  2.220196   97056.487367
# 18     Xiaomi  14.450000  10.000000  1.620000   99631.353750
# 4        Dell  15.136027   9.151515  2.147040  104255.464212
# 16    Toshiba  14.354167   8.666667  1.640208  111440.718750
# 15    Samsung  13.822222  10.666667  1.315556  124241.766667
# 8      Huawei  13.000000   8.000000  1.050000  125169.600000
# 1       Apple  13.247619   9.333333  1.320476  137493.054429
# ...

# %%
plt.figure(figsize=(15,8))
sns.barplot(x='Company',y='price_rs',data=k)
# Out:
# <AxesSubplot:xlabel='Company', ylabel='price_rs'>

# %% [markdown]
# ## VERO LAPTOPS ARE CHEAPER AND RAZER LAPTOPS ARE COSTLY

# %%
l=df.groupby('Company',as_index=False).mean().sort_values(by='Weight')
plt.figure(figsize=(15,6))
sns.barplot(x='Company',y='Weight',data=l)
# Out:
# <AxesSubplot:xlabel='Company', ylabel='Weight'>

# %% [markdown]
# ## MSI LAPTOPS ARE HEAVIER IN WEIGHT AND LG LAPTOPS ARE LIGHTER

# %%
df['TypeName'].value_counts().plot.pie(y=df['TypeName'],figsize=(30,25),autopct='%1.1f')
# Out:
# <AxesSubplot:ylabel='TypeName'>

# %%
p=df.groupby('TypeName',as_index=False).mean().sort_values(by='price_rs')
plt.figure(figsize=(15,6))
sns.barplot(x='TypeName',y='price_rs',data=p)
# Out:
# <AxesSubplot:xlabel='TypeName', ylabel='price_rs'>

# %% [markdown]
# ## PRICE OF NETBOOK AND NOTEBOOK ARE LESS WHEREAS THE PRICE OF WORKSTATION AND GAMING LAPTOPS ARE HIGHER

# %%
df['Inches'].value_counts().plot.pie(y=df['Inches'],figsize=(50,45),autopct='%1.1f')
# Out:
# <AxesSubplot:ylabel='Inches'>

# %% [markdown]
# ## MOST OF THE LAPTOPS ARE OF 15.6 INCHES

# %%
## LETS TRY TO FIND RELATION BETWEEN INCHES AND PRICE OF THE LAPTOP
i=df.groupby('Inches',as_index=False).mean().sort_values(by='price_rs')

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='Inches',y='price_rs',data=i)
# Out:
# <AxesSubplot:xlabel='Inches', ylabel='price_rs'>

# %%
## For most of the cases price of the laptops is increasing with inches

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight    price_rs
# 0  Intel Iris Plus Graphics 640  macOS    1.37  117758.751
# ...

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
# here we can extract many inforamtion like touchscreen, whether IPS panel is present or not, Full hd display or not

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x: 1 if 'Touchscreen' in x else 0)

# %%
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
df['Touchscreen'].value_counts()
# Out:
# 0    1111
# 1     192
# Name: Touchscreen, dtype: int64

# %%
sns.barplot(x=df['Touchscreen'],y=df['price_rs'])
# Out:
# <AxesSubplot:xlabel='Touchscreen', ylabel='price_rs'>

# %% [markdown]
# ### LAPTOPS HAVING TOUCHSCREEN FEATURE ARE EXPENSIVE

# %%
df['IPS']=df['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight    price_rs  Touchscreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37  117758.751            0    1
# ...

# %%
df['IPS'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x='IPS',y='price_rs',data=df)
# Out:
# <AxesSubplot:xlabel='IPS', ylabel='price_rs'>

# %% [markdown]
# ### price of IPS display is more

# %%
## now we have to extract resolution i.e., x resolution and y resolution

# %%
df['x_resolution']=df['ScreenResolution'].str.split('x').str[0]
df['y_resolution']=df['ScreenResolution'].str.split('x').str[1]

# %%
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
## now we need to do something of x resolution
## lets use regular expression

# %%
df['x_resolution']=df['x_resolution'].str.replace(',','').str.findall(r'(\d+\.?\d+)')

# %%
df['x_resolution']=df['x_resolution'].str[0]

# %%
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
df['x_resolution']=df['x_resolution'].astype(int)
df['y_resolution']=df['x_resolution'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float64
#  11  price_rs          1303 non-null   float64
#  12  Touchscreen       1303 non-null   int64
#  13  IPS               1303 non-null   int64
#  14  x_resolution      1303 non-null   int32
#  15  y_resolution      1303 non-null   int32
# ...

# %%
df.corr()
# Out:
#                 Inches       Ram    Weight  price_rs  Touchscreen       IPS  \
# Inches        1.000000  0.237993  0.827631  0.068197    -0.361735 -0.114804
# Ram           0.237993  1.000000  0.383874  0.743007     0.116984  0.206623
# Weight        0.827631  0.383874  1.000000  0.210370    -0.294620  0.016967
# price_rs      0.068197  0.743007  0.210370  1.000000     0.191226  0.252208
# Touchscreen  -0.361735  0.116984 -0.294620  0.191226     1.000000  0.150512
# IPS          -0.114804  0.206623  0.016967  0.252208     0.150512  1.000000
# x_resolution -0.071245  0.433121 -0.032880  0.556529     0.351066  0.281457
# y_resolution -0.071245  0.433121 -0.032880  0.556529     0.351066  0.281457
#
#               x_resolution  y_resolution
# Inches           -0.071245     -0.071245
# Ram               0.433121      0.433121
# Weight           -0.032880     -0.032880
# price_rs          0.556529      0.556529
# Touchscreen       0.351066      0.351066
# ...

# %%
df.corr()['price_rs']
# Out:
# Inches          0.068197
# Ram             0.743007
# Weight          0.210370
# price_rs        1.000000
# Touchscreen     0.191226
# IPS             0.252208
# x_resolution    0.556529
# y_resolution    0.556529
# Name: price_rs, dtype: float64

# %%
## lets make a new column ppi(pixel per inches)
df['ppi'] = (((df['x_resolution']**2) + (df['y_resolution']**2))**0.5/df['Inches']).astype('float')

# %%
df['ppi']
# Out:
# 0       272.209528
# 1       153.117859
# 2       174.057054
# 3       264.476303
# 4       272.209528
#            ...
# 1298    193.949289
# 1299    340.261910
# 1300    137.986838
# 1301    123.834341
# 1302    123.834341
# Name: ppi, Length: 1303, dtype: float64

# %%
df.corr()['price_rs']
# Out:
# Inches          0.068197
# Ram             0.743007
# Weight          0.210370
# price_rs        1.000000
# Touchscreen     0.191226
# IPS             0.252208
# x_resolution    0.556529
# y_resolution    0.556529
# ppi             0.474973
# Name: price_rs, dtype: float64

# %%
df.drop(columns=['Inches','x_resolution','y_resolution'],inplace=True)

# %%
df
# Out:
#      Company                              Product            TypeName  \
# 0      Apple                          MacBook Pro           Ultrabook
# 1      Apple                          Macbook Air           Ultrabook
# 2         HP                               250 G6            Notebook
# 3      Apple                          MacBook Pro           Ultrabook
# 4      Apple                          MacBook Pro           Ultrabook
# ...      ...                                  ...                 ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# ...

# %%
df.drop('ScreenResolution',axis=1,inplace=True)

# %%
df.head()
# Out:
#   Company      Product   TypeName                         Cpu  Ram  \
# 0   Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#      price_rs  Touchscreen  IPS         ppi
# 0  117758.751            0    1  272.209528
# 1   79016.826            0    0  153.117859
# ...

# %%
# LETS TALK ABOUT CPU
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['cpu_name']=df['Cpu'].apply(lambda x: ' '.join(x.split()[0:3]))

# %%
df
# Out:
#      Company                              Product            TypeName  \
# 0      Apple                          MacBook Pro           Ultrabook
# 1      Apple                          Macbook Air           Ultrabook
# 2         HP                               250 G6            Notebook
# 3      Apple                          MacBook Pro           Ultrabook
# 4      Apple                          MacBook Pro           Ultrabook
# ...      ...                                  ...                 ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#                                        Cpu  Ram               Memory  \
# ...

# %%
def fetch_processor(text):
    if text=='Intel Core i5' or text=='Intel Core i7' or text=='Intel Core i3':
        return text
    else:
        if text.split()[0]=='Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['CPU_BRAND']=df['cpu_name'].apply(fetch_processor)

# %%
df
# Out:
#      Company                              Product            TypeName  \
# 0      Apple                          MacBook Pro           Ultrabook
# 1      Apple                          Macbook Air           Ultrabook
# 2         HP                               250 G6            Notebook
# 3      Apple                          MacBook Pro           Ultrabook
# 4      Apple                          MacBook Pro           Ultrabook
# ...      ...                                  ...                 ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#                                        Cpu  Ram               Memory  \
# ...

# %%
df['CPU_BRAND'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
e=df.groupby('CPU_BRAND',as_index=False).mean().sort_values(by='price_rs')

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='CPU_BRAND',y='price_rs',data=e)
# Out:
# <AxesSubplot:xlabel='CPU_BRAND', ylabel='price_rs'>
